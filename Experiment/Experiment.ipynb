# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
soil_name = pd.read_csv('Soil_Name.csv')

soil_name_list = list(soil_name)

print(len(soil_name_list))
soil_name_list
# Out:
# 91
# ['name',
#  'om0-5',
#  'om5-10',
#  'om10-15',
#  'om15-30',
#  'om30-45',
#  'om45-60',
#  'om60-80',
#  'om80-100',
#  'om100-120',
#  'dul0-5',
#  'dul5-10',
#  'dul10-15',
#  'dul15-30',
#  'dul30-45',
#  'dul45-60',
#  'dul60-80',
#  'dul80-100',
#  'dul100-120',
#  'sand0-5',
#  'sand5-10',
#  'sand10-15',
#  'sand15-30',
#  'sand30-45',
#  'sand45-60',
#  'sand60-80',
#  'sand80-100',
#  'sand100-120',
#  'sat0-5',
#  'sat5-10',
#  'sat10-15',
#  'sat15-30',
#  'sat30-45',
#  'sat45-60',
#  'sat60-80',
#  'sat80-100',
#  'sat100-120',
#  'ksat0-5',
#  'ksat5-10',
#  'ksat10-15',
#  'ksat15-30',
#  'ksat30-45',
#  'ksat45-60',
#  'ksat60-80',
#  'ksat80-100',
#  'ksat100-120',
#  'll0-5',
#  'll5-10',
#  'll10-15',
#  'll15-30',
#  'll30-45',
#  'll45-60',
#  'll60-80',
#  'll80-100',
#  'll100-120',
#  'clay0-5',
#  'clay5-10',
#  'clay10-15',
#  'clay15-30',
#  'clay30-45',
#  'clay45-60',
#  'clay60-80',
#  'clay80-100',
#  'clay100-120',
#  'bddry0-5',
# ...

# %%
dataset = pd.read_csv('Weather_Name.csv')

weather_name = list(dataset)

print(len(weather_name))

for name in weather_name:
    print(name)
# Out:
# 441
# name
# 'Prcp Week 13'
# 'Tmax Week 13'
# 'Tmin Week 13'
# 'Srad Week 13'
# 'Gdd Week 13'
# 'Rdays Week 13'
# 'Exrain Week 13'
# 'Cldays Week 13'
# 'Hdays Week 13'
# 'Codays Week 13'
# 'Hunits Week 13'
# 'Prcp Week 14'
# 'Tmax Week 14'
# 'Tmin Week 14'
# 'Srad Week 14'
# 'Gdd Week 14'
# 'Rdays Week 14'
# 'Exrain Week 14'
# 'Cldays Week 14'
# 'Hdays Week 14'
# 'Codays Week 14'
# 'Hunits Week 14'
# 'Prcp Week 15'
# 'Tmax Week 15'
# 'Tmin Week 15'
# 'Srad Week 15'
# 'Gdd Week 15'
# 'Rdays Week 15'
# 'Exrain Week 15'
# 'Cldays Week 15'
# 'Hdays Week 15'
# 'Codays Week 15'
# 'Hunits Week 15'
# 'Prcp Week 16'
# 'Tmax Week 16'
# 'Tmin Week 16'
# 'Srad Week 16'
# 'Gdd Week 16'
# 'Rdays Week 16'
# 'Exrain Week 16'
# 'Cldays Week 16'
# 'Hdays Week 16'
# 'Codays Week 16'
# 'Hunits Week 16'
# 'Prcp Week 17'
# 'Tmax Week 17'
# 'Tmin Week 17'
# 'Srad Week 17'
# 'Gdd Week 17'
# 'Rdays Week 17'
# 'Exrain Week 17'
# 'Cldays Week 17'
# 'Hdays Week 17'
# 'Codays Week 17'
# 'Hunits Week 17'
# ...
